# %% [markdown]
# # TP2: Estimación de peso y dimensiones de los envíos de Mercado Libre
#
# # Materia: Análisis y curación de datos
#
# ## Análisis del dataset
#
# Se pide: A partir de lo visto en la teoría de la materia y del segundo laboratorio, diagramar una comunicación en formato textual o interactivo describiendo la solución de las actividades propuestas a continuación. Al final de las mismas se proveen actividades opcionales (no obligatorias) que pueden resultar de interés.
#
# ### Actividades Propuestas:
#     1.	Eliminar valores cuyo status sea `404` , luego eliminar la columna `status` del dataset ya que solo es útil para limpieza.
#
#     2.	Eliminar los valores NaN de las columnas con prefijo `SHP_`. Estas son aquellas que representan o peso o dimensiones de un item.
#
#     3.	Agrupar por item id y calcular mediana de peso y medidas. De esta forma debería quedar una única fila por cada item_id.
#
#     4.	Parsear la columna de atributos y extraer a columnas propias aquellos atributos cuyo `id` sea `BRAND` o `MODEL`. Estos atributos representan marca o modelo que el vendedor del item ingresó en la publicación. [Opcional] No es necesario limitarse a estos dos atributos, se puede probar quedarse con los N atributos más frecuentes.
#
#     5.	Transformar variables categóricas en números (Se recomienda OneHotEncoding) para las columnas (Sugerencia: arrancar con un sample de ~10K items)
#
#         a.	`CATALOG_PRODUCT_ID`
#         b.	`CONDITION`
#         c.	`DOMAIN_ID`
#         d.	`SELLER_ID`
#         e.	`BRAND` (extraída en 4)
#         f.	`MODEL`(extraída en 4)
#
#     6.	En caso de tener alguna variable no medida (en nuestro caso `PRICE`) imputar sus valores utilizando kNN.
#
#     7.	Medir las distribuciones de las variables como histogramas, realizar normalizaciones e identificar outliers con los métodos vistos en clase. Hacer análisis de estos outliers y considerar si sería correcto o no eliminarlos del dataset. Sugerencia: Identificar outliers de las columnas `SHP_WEIGHT` y `SHP_VOLUME`, donde `SHP_VOLUME` se define como el producto de las dimensiones.
#
#     8.	[Opcional] Si están interesados en usar texto y técnicas de NLP sobre el título:
#         a.	Realizar preprocesamiento del texto, se recomienda leer este artículo.
#         b.	Para convertir el título en vectores se recomienda ver tf-idf. wiki, sklearn.
#
#     9.	[Opcional] Aplicar PCA y decidir si existe un subespacio del espacio de features donde viven los datos y son bien descriptos. Graficar.
#
#     10.	[Opcional] Aplicar Mixturas Gaussianas (GMM) para hacer clustering.
#
# La comunicación debe estar apuntada a un público técnico pero sin conocimiento del tema particular, como por ejemplo, sus compañeros de clase o stakeholders del proyecto. Idealmente, además del documento se debería generar una presentación corta para stakeholders explicando el análisis realizado sobre los datos y las conclusiones obtenidas de tal análisis.
#
# Se evaluarán los siguientes aspectos:
#
#     ●	El informe debe contener un mensaje claro y presentado de forma concisa.
#     ●	Los gráficos deben aplicar los conceptos de percepción visual vistos en clase.
#     ●	Se debe describir o estimar la significancia estadística de su trabajo.

# %%
# pip install scikit-learn

# %%
import pandas as pd
import random
import matplotlib.pyplot as plt
import numpy as np
import seaborn
import scipy as sc
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelBinarizer
from ast import literal_eval
from pandas.io.json import json_normalize
#import json

# %%
random.seed(0)

# %% [markdown]
# El dataset corresponde a un muestreo de envíos durante tres meses de 2018 en MLB (Mercado Libre Brasil), filtrados según métodos de envíos y por carriers (empresas de correos a cargo del envío propiamente dicho). A su vez, fue muestreado de forma no uniforme para romper de forma manual la distribución de los datos.
# Los datos son:[meli_dataset_20190426.csv] (https://drive.google.com/open?id=1tNUKD1lf1z8C7LPpCruiDl6SKBAHb79v).

# %%
DATASET = 'meli_dataset_20190426.csv'

# %%
df_original = pd.read_csv(DATASET, low_memory=False)

# %%
df= df_original

# %%
df = df.head(10000)

# %%
df.columns
# Out:
# Index(['ITEM_ID', 'SHP_WEIGHT', 'SHP_LENGTH', 'SHP_WIDTH', 'SHP_HEIGHT',
#        'ATTRIBUTES', 'CATALOG_PRODUCT_ID', 'CONDITION', 'DOMAIN_ID', 'PRICE',
#        'SELLER_ID', 'STATUS', 'TITLE'],
#       dtype='object')

# %% [markdown]
# #### ¿Qué significa cada columna?
#
# * ITEM_ID: id unívoco de cada item publicado. (Ofuscado)
# * SHP_WEIGHT: peso del paquete informado por el correo.
# * SHP_LENGTH: largo del paquete informado por el correo.
# * SHP_WIDTH: ancho del paquete informado por el correo.
# * SHP_HEIGHT: altura del paquete informado por el correo.
# * ATTRIBUTES: atributos como marca y modelo, entre otros, en formato json-lines
# * CATALOG_PRODUCT_ID: id del catálogo (ofuscado).
# * CONDITION: condición de venta (nuevo o usado).
# * DOMAIN_ID: id de la categoría a la que pertenece la publicación.
# * PRICE: precio en reales.
# * SELLER_ID: id del vendedor (ofuscado).
# * STATUS: estado de la publicación (activa, cerrada, pausada, etc.)
# * TITLE: título de la publicación.

# %%
df.sample(5)
# Out:
#          ITEM_ID  SHP_WEIGHT  SHP_LENGTH  SHP_WIDTH  SHP_HEIGHT  \
# 2318  JFM04MT51C         NaN         NaN        NaN         NaN
# 4869  N6UTS0VOQY         NaN         NaN        NaN         NaN
# 6867  GWL3IS38BW       450.0        20.0       15.0        10.0
# 9072  IC83MFPBGA       790.0        25.0       15.0        10.0
# 6159  DLXSVB9EZW         NaN         NaN        NaN         NaN
#
#                                              ATTRIBUTES CATALOG_PRODUCT_ID  \
# 2318  [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...         H53U1H7Q5G
# 4869                                                NaN         H53U1H7Q5G
# 6867                                                NaN         H53U1H7Q5G
# 9072                                                NaN         H53U1H7Q5G
# 6159  [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...         H53U1H7Q5G
#
#      CONDITION                        DOMAIN_ID  PRICE   SELLER_ID  \
# 2318       new  MLB-MOTORCYCLE_REARVIEW_MIRRORS   85.0  JO7VRVUB6V
# 4869       NaN                              NaN    NaN  ZZCQI0F60G
# 6867       NaN                              NaN    NaN  LNS8XIJ5ZU
# 9072       NaN                              NaN    NaN  JFUNO93YYC
# 6159       new  MLB-TOOL_ACCESSORIES_AND_SPARES   55.9  ALDW2HR7S7
#
#             STATUS                                              TITLE
# 2318        active  Retrovisor Gs 650 F800 Bmw Titan Cb Xre Rosca ...
# 4869  under_review  Camisa Dry Fit Masculina Cores Diversas Atacad...
# 6867  under_review  Tv Box Mx9 4k Android 7 2gb Ram Hdmi Wi-fi You...
# 9072  under_review  Máquina De Corte Andis Envy Li Cordless Sem Fi...
# 6159        active  Kit 5 Brocas Fresas Forstner Madeira  15 20 25...

# %%
df.dtypes
# Out:
# ITEM_ID                object
# SHP_WEIGHT            float64
# SHP_LENGTH            float64
# SHP_WIDTH             float64
# SHP_HEIGHT            float64
# ATTRIBUTES             object
# CATALOG_PRODUCT_ID     object
# CONDITION              object
# DOMAIN_ID              object
# PRICE                 float64
# SELLER_ID              object
# STATUS                 object
# TITLE                  object
# dtype: object

# %% [markdown]
# ## Actividad 1:
#
# Eliminar valores cuyo status sea `404` , luego eliminar la columna `status` del dataset ya que solo es útil para limpieza.

# %%
# df.filter(["STATUS"])!= "404"

df = df[df.STATUS != "404"]
df = df.drop(columns=['STATUS'])
df.sample(5)
# Out:
#          ITEM_ID  SHP_WEIGHT  SHP_LENGTH  SHP_WIDTH  SHP_HEIGHT  \
# 3733  BRYX8VIR0V         NaN         NaN        NaN         NaN
# 9314  OXD96CD19W       100.0        16.0       16.0         5.0
# 3500  JTR3TH85SV         NaN         NaN        NaN         NaN
# 3384  QAJ7HVTLFA       160.0        16.0       15.0        10.0
# 3355  IO2PJAQO43       620.0        20.0       19.0        18.0
#
#                                              ATTRIBUTES CATALOG_PRODUCT_ID  \
# 3733  [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...         H53U1H7Q5G
# 9314                                                NaN         H53U1H7Q5G
# 3500                                                NaN         H53U1H7Q5G
# 3384  [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...         H53U1H7Q5G
# 3355  [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...         V8E85HCRII
#
#      CONDITION                       DOMAIN_ID   PRICE   SELLER_ID  \
# 3733       new  MLB-AUDIO_AND_VIDEO_CONNECTORS   29.99  R9P7XSOBC5
# 9314       NaN                             NaN     NaN  EN79FAMVHD
# 3500       NaN                             NaN     NaN  FGOEDLBB99
# 3384       new             MLB-CAR_OIL_FILTERS  110.00  B4QOJAUV4A
# 3355       new      MLB-VIDEO_GAME_CONTROLLERS  285.49  XULFTOUXF9
#
#                                                   TITLE
# 3733  02 Soquete Socket Lga 1155 Dt Bgadesk Original...
# 9314  Tela Touch Display Samsung J510 J5 2016 Origin...
# 3500  Kit Sandália Rasteira Melissa Com 10 Pares Enf...
# 3384    Filtro Óleo De Câmbio Dsg Jetta / Passat / Audi
# 3355  Controle Xbox One S Original Microsoft Slim Br...

# %% [markdown]
# ## Actividad 2:
#
# Eliminar los valores NaN de las columnas con prefijo `SHP_`. Estas son aquellas que representan o peso o dimensiones de un item.

# %%
# df = df.dropna(subset=['SHP_WEIGHT'])
# df = df.dropna(subset=['SHP_LENGTH'])
# df = df.dropna(subset=['SHP_WIDTH'])
# df = df.dropna(subset=['SHP_HEIGHT'])

# o bien:
df = df.dropna(subset=['SHP_WEIGHT', 'SHP_LENGTH', 'SHP_WIDTH', 'SHP_HEIGHT'])

#o bien

# df= df.dropna(df.filter(regex ='SHP_'))

#df.sample(3)

# %% [markdown]
# ## Actividad 3:
#
# Agrupar por item id y calcular mediana de peso y medidas. De esta forma debería quedar una única fila por cada item_id.

# %%
# Agrupamos por item_id
df_grouped = df.groupby(['ITEM_ID'], as_index=False).median()
#Ordenamos el dataframe por item_id
df.sort_values('ITEM_ID', inplace = True)
# Eliminamos filas con item_id duplicados
df.drop_duplicates(subset='ITEM_ID', keep=False, inplace=True)
# Actualizamos dataframe original con la mediana de pesos y medidas
df.set_index('ITEM_ID', inplace=True)
df.update(df_grouped.set_index('ITEM_ID', inplace=True))
df.reset_index()
# Out:
#          ITEM_ID  SHP_WEIGHT  SHP_LENGTH  SHP_WIDTH  SHP_HEIGHT  \
# 0     A0BKGTRNTM       775.0        50.0       20.0        10.0
# 1     A0JIHFAMOP      6100.0        70.0       25.0         5.0
# 2     A0NG260OMQ       464.0        20.0       11.0        10.0
# 3     A0WL6O455O       150.0        25.0       25.0        11.0
# 4     A1957258HH      3719.0        42.0       34.0        13.0
# 5     A1FGLFZMVL       729.0        25.0       25.0         5.0
# 6     A1JOTAU8V2      1750.0        41.0       41.0        28.0
# 7     A1LOUCXG9G       150.0        25.0       25.0         5.0
# 8     A2C66XB6P7      3084.0        65.0       20.0         5.0
# 9     A2KCXCBL57       640.0        21.5       18.4        14.3
# 10    A2RQ980UVM       340.0        20.0       20.0        20.0
# 11    A3MNDIW032        35.0         0.0        0.0         0.0
# 12    A43U8UOWPI       552.0        37.0       27.0         3.0
# 13    A4G70EIGUH       483.0        19.0       15.0         9.0
# 14    A4N2QZXPXK       250.0        25.0       25.0         5.0
# 15    A56OPIMS0D     18600.0        30.0       21.0        15.0
# 16    A5IQMUAC28       429.0        20.0       20.0        20.0
# 17    A5M6IPYV6M       650.0        57.0       24.0        16.0
# 18    A5VAXDE1G8       561.0        30.0       30.0        30.0
# 19    A61JSUNHMI       599.0        34.0       29.0        25.0
# 20    A6TAE435H1       120.0        19.0       14.9         9.2
# 21    A7EZZ96IDB      1335.0        29.0        0.0         0.0
# 22    A7F2YZUXKV     22000.0        71.0       60.0        55.0
# 23    A87VLI4UUY       714.0        16.0       11.0         2.0
# 24    A8GKANTGUK      3820.0        40.0       25.0        15.0
# 25    A8IVK9CICB       560.0        23.0       16.0         4.0
# 26    A8Y5P3MCVJ       200.0        16.0       11.0         2.0
# 27    A9495T93S4       654.0        25.0       25.0         5.0
# 28    A9CQEUN6IU      2500.0        50.0       40.0        17.0
# 29    A9GGUJPPSA       178.0        25.0       25.0         5.0
# ...          ...         ...         ...        ...         ...
# 3962  ZU48DBNUUA        70.0        16.0       11.0         2.0
# 3963  ZU4ZP1JHMN      3100.0        30.0       30.0        20.0
# 3964  ZU718W1552       800.0        25.0        0.0         0.0
# 3965  ZUP27NZFS3     12205.0        31.0       21.0        20.0
# 3966  ZUXD6OD8M8      1260.0        45.0       45.0        18.0
# 3967  ZV3JHGL1ID       150.0        30.0       15.0         5.0
# 3968  ZV3X8Y08U4      4800.0        74.0       31.0        26.0
# 3969  ZVI8QNVYMF     10500.0        30.0       30.0        30.0
# 3970  ZVPL70J9OG      4260.0        23.0       22.0        20.0
# 3971  ZW5TA6CP0X      4650.0        74.0       53.0        35.0
# 3972  ZWA6IVO4NM       448.0        24.0       14.0         8.0
# 3973  ZWOU76VN42       300.0        19.0       14.0         8.0
# 3974  ZWRX53K52L      1870.0        38.0       19.0        13.0
# 3975  ZWT684RYRA       380.0        18.0       13.0         4.0
# 3976  ZWWQQV4FWN       404.0        18.0       18.0        10.0
# 3977  ZX4STUTFBN       350.0        24.0       18.0        10.0
# 3978  ZXIAW22XI3       500.0        16.0       11.0         5.0
# 3979  ZXT4P7WYU5      1900.0        30.0       20.0        15.0
# 3980  ZXVQ7O6NDG     11700.0        35.0       28.0        28.0
# 3981  ZXY1TK6LFC      2100.0        25.0       25.0        15.0
# 3982  ZXZXFADE2B        80.0        16.0       11.0         5.0
# 3983  ZYD4THZKT0     10000.0        77.0       66.0        10.0
# 3984  ZYNLMDVYEG       852.0        45.0       34.0        28.0
# 3985  ZYR4SBZB4H       355.0        25.0       11.0         5.0
# 3986  ZYUOIR3H5I     15800.0        83.0       79.0        33.0
# 3987  ZZ50AZ3OAK       431.0        25.0       25.0         5.0
# 3988  ZZ8ERDIFP4       150.0        20.0       20.0        20.0
# 3989  ZZFFUBJ43D      3880.0        36.0       24.0        13.0
# 3990  ZZWAKWIMPT      1040.0        28.0       18.0         8.0
# 3991  ZZXLYGKXNE       260.0        16.0       11.0         2.0
#
#                                              ATTRIBUTES CATALOG_PRODUCT_ID  \
# 0     [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...         H53U1H7Q5G
# 1     [{'id': 'BEDDING_SET_SIZE', 'name': 'Tamanho',...         H53U1H7Q5G
# 2     [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...         H53U1H7Q5G
# 3     [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...         H53U1H7Q5G
# 4     [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...         GITRVCM7WO
# 5     [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...         H53U1H7Q5G
# 6     [{'id': 'AMBIENTS', 'name': 'Ambientes', 'valu...         H53U1H7Q5G
# 7     [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...         H53U1H7Q5G
# 8     [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...         H53U1H7Q5G
# 9     [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...         H53U1H7Q5G
# 10    [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...         H53U1H7Q5G
# 11                                                  NaN         H53U1H7Q5G
# 12    [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...         H53U1H7Q5G
# 13    [{'id': 'ANSWERING_MACHINE', 'name': 'Secretár...         N7KWH454XN
# 14    [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...         H53U1H7Q5G
# 15    [{'id': 'BAR_DIMETER', 'name': 'Diâmetro', 'va...         H53U1H7Q5G
# 16    [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...         H53U1H7Q5G
# 17    [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...         H53U1H7Q5G
# 18    [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...         H53U1H7Q5G
# 19    [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...         H53U1H7Q5G
# 20    [{'id': 'BRAKE_LIGHT_SWITCH_TYPE', 'name': 'Ti...         H53U1H7Q5G
# 21                                                  NaN         H53U1H7Q5G
# 22    [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...         H53U1H7Q5G
# 23    [{'id': 'BATTERY_CAPACITY', 'name': 'Capacidad...         VIQBB4LQZG
# 24    [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...         KP0EXWRQRZ
# 25    [{'id': 'ITEM_CONDITION', 'name': 'Condição do...         H53U1H7Q5G
# 26    [{'id': 'ACCESSORY_TYPE', 'name': 'Tipo de ace...         H53U1H7Q5G
# 27                                                  NaN         H53U1H7Q5G
# 28    [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...         H53U1H7Q5G
# 29    [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...         H53U1H7Q5G
# ...                                                 ...                ...
# 3962                                                NaN         H53U1H7Q5G
# 3963  [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...         VFPC539YCQ
# 3964                                                NaN         H53U1H7Q5G
# 3965  [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...         H53U1H7Q5G
# 3966  [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...         H53U1H7Q5G
# 3967  [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...         H53U1H7Q5G
# 3968  [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...         H53U1H7Q5G
# 3969  [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...         H53U1H7Q5G
# 3970                                                NaN         H53U1H7Q5G
# 3971  [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...         H53U1H7Q5G
# 3972                                                NaN         H53U1H7Q5G
# 3973  [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...         H53U1H7Q5G
# 3974  [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...         H53U1H7Q5G
# 3975                                                NaN         H53U1H7Q5G
# 3976  [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...         H53U1H7Q5G
# 3977  [{'id': 'BLADE_LENGTH', 'name': 'Comprimento d...         H53U1H7Q5G
# 3978  [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...         H53U1H7Q5G
# 3979  [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...         H53U1H7Q5G
# 3980  [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...         H53U1H7Q5G
# 3981  [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...         ZUZF6Q39W8
# 3982  [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...         H53U1H7Q5G
# 3983                                                NaN         H53U1H7Q5G
# 3984  [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...         H53U1H7Q5G
# 3985  [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...         H53U1H7Q5G
# 3986  [{'id': '3_IN_1', 'name': 'É 3 em 1', 'value_i...         OCZOFJPJVF
# 3987  [{'id': 'CLOSING', 'name': 'Fecho', 'value_id'...         H53U1H7Q5G
# 3988  [{'id': 'ITEM_CONDITION', 'name': 'Condição do...         H53U1H7Q5G
# 3989  [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...         H53U1H7Q5G
# 3990  [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...         CCNZQYJ1G6
# 3991                                                NaN         H53U1H7Q5G
#
#      CONDITION                                        DOMAIN_ID    PRICE  \
# 0          new                           MLB-ENGINE_GASKET_SETS   750.00
# 1          new                                 MLB-BEDDING_SETS   119.90
# 2          new                        MLB-AUTOMOBILE_FUEL_PUMPS   349.90
# 3          new                                    MLB-PENDRIVES    21.99
# 4         used                                MLB-GAME_CONSOLES   849.00
# 5          new                                       MLB-SHORTS   148.90
# 6          new                               MLB-CEILING_LIGHTS   130.00
# 7          new                              MLB-FOOTBALL_SHIRTS    57.90
# 8          new                                  MLB-TRANSISTORS   162.00
# 9          new                                         MLB-MUGS    63.60
# 10         new                          MLB-VEHICLE_ACCESSORIES   369.80
# 11         NaN                                              NaN      NaN
# 12         new            MLB-AUTOMOTIVE_ENGINE_OIL_FILLER_CAPS    10.80
# 13         new                                   MLB-TELEPHONES   120.90
# 14         new                                     MLB-CLOTHING    25.00
# 15         new                                     MLB-GYM_BARS   119.00
# 16         new                MLB-MOTORCYCLE_GASOLINE_TANK_CAPS    55.00
# 17         new                       MLB-CONSTRUCTION_MATERIALS   166.90
# 18         new                          MLB-VEHICLE_ACCESSORIES    15.90
# 19         new                                    MLB-SOUVENIRS    55.00
# 20         new                         MLB-BRAKE_LIGHT_SWITCHES    92.00
# 21         NaN                                              NaN      NaN
# 22         new                             MLB-KITCHEN_CABINETS   119.90
# 23         new                               MLB-WALKIE_TALKIES    99.00
# 24         new                               MLB-CAMERA_TRIPODS   759.99
# 25         new                                        MLB-BOOKS    61.63
# 26         new                          MLB-VEHICLE_ACCESSORIES    26.99
# 27         NaN                                              NaN      NaN
# 28         new                                    MLB-GARDENING   119.00
# 29         new                                MLB-BABY_CLOTHING    60.00
# ...        ...                                              ...      ...
# 3962       NaN                                              NaN      NaN
# 3963       new                             MLB-CAR_AV_RECEIVERS   276.98
# 3964       NaN                                              NaN      NaN
# 3965       new                               MLB-AIRGUN_PELLETS   559.90
# 3966       new                       MLB-BREAST_FEEDING_PILLOWS    44.88
# 3967       new                                 MLB-WRISTWATCHES    55.99
# 3968       new                        MLB-AUTOMOTIVE_HEADLIGHTS   322.00
# 3969       new                                MLB-POOL_CHLORINE   113.00
# 3970       NaN                                              NaN      NaN
# 3971       new                                     MLB-CUSHIONS   149.94
# 3972       NaN                                              NaN      NaN
# 3973       new                     MLB-TEETH_WHITENING_PRODUCTS    61.90
# 3974       new                        MLB-ELECTRIC_CREPE_MAKERS   335.08
# 3975       NaN                                              NaN      NaN
# 3976       new                  MLB-TOOL_ACCESSORIES_AND_SPARES   169.90
# 3977       new      MLB-TACTICAL_AND_SPORTING_KNIVES_AND_BLADES    17.77
# 3978       new          MLB-MOTORCYCLE_STARTER_SWITCH_IGNITIONS    26.35
# 3979       new  MLB-HOME_APPLIANCES_ACCESSORIES_AND_SPARE_PARTS    13.99
# 3980       new                              MLB-HAIR_TREATMENTS   239.90
# 3981       new                                  MLB-SPICE_RACKS    59.00
# 3982       new                                     MLB-CLOTHING    69.00
# 3983       NaN                                              NaN      NaN
# 3984       new                                   MLB-FAKE_CAKES   119.90
# 3985       new                             MLB-TABLET_KEYBOARDS    42.99
# 3986       new                               MLB-BABY_STROLLERS  1019.99
# 3987       new                                  MLB-FANNY_PACKS    69.90
# 3988       new                  MLB-PORTABLE_ELECTRIC_MASSAGERS     7.50
# 3989       new                                  MLB-ENGINE_OILS   145.90
# 3990       new                                      MLB-ROUTERS   329.49
# 3991       NaN                                              NaN      NaN
#
#        SELLER_ID                                              TITLE
# 0     QD3YJ9751S     Jogo De Junta Completo Civic 93hfa55507z200167
# 1     J3EY3QAB29  Mosquiteiro De Armação Infantil Solteiro Completo
# 2     NO4W1R9S3D  Refil Bomba Combustível Gasolina Hyundai Vera ...
# 3     KIQX6YQZI4    Pen Drive 8gb Multilaser Twist Original Lacrado
# 4     ZQIKYCCZ7E            Playstation 3-ps3+brinde Hdmi + 9 Jogos
# 5     KAKDL9XJW3  Shorts Masculino Bermuda Praia Estampado Kit 5...
# 6     P0XSEGDPNX             Kit 2 Pendentes Arandela Chapéu Chinês
# 7     K2T5AAE8TW  Kit Brasil + Kit Palmeiras 2018 Brasileira Cam...
# 8     ZJ1TIFHVWB  Dissipador De Calor De Aluminio 17,2cm Largura...
# 9     DM7LDQI5CB  2 Xícara De Café Expresso Flashy Roxa  - Ref 7268
# 10    HT48IWCZFX  Bomba De Gasolina Ténéré600 / Super-ténéré750 ...
# 11    LUVK3DWCM4            Cartao Micro Sd 128gb Classe 10 Sandisk
# 12    ZNBCPDD1J7  Tampa Reservatório Água Limpador Peugeot 206 2...
# 13    FPUT1805KQ    Telefone Sem Fio Ts 63 V Preto Teclado Luminoso
# 14    ZNOQF4WJH6  Cropped Blusa Feminina Canelada Manga Longa Bo...
# 15    K9KCGSOYTG  Kettlebel Acabemia Musculação Emborrachado Kit...
# 16    WBI9BFFQEH           Tampa Do Tanque Dt 180 / Dtn 180 85 A 92
# 17    FL9V1P8LLY  Acabamento Registro De Gaveta 1/2 , 3/4 E 1'' ...
# 18    FS4CHWBK0Q     Vonixx Rejuvex 400g Revitalizador De Plásticos
# 19    NNFG4DL8NF  Maleta Para Pajem, Segurança Das Alianças Casa...
# 20    ZNBCPDD1J7  Interruptor Freio Hyundai Tucson Santa Fe Ix35...
# 21    GPCD04T8YP    Kit 5 Calças Legging Montaria Feminina  Atacado
# 22    JRZHZ82GF1  Balcão Armário Gabinete Cooktop 05 Bocas Cozin...
# 23    YUX9ZW0CJL   Radio Comunicador Walk Talk Baofeng 777s C/ Fone
# 24    W1FC2AHMEA  Tripé Profissional Com Cabeça Hidráulica Video...
# 25    Y7V8A05UPD               Massagem Para O Desempenho Esportivo
# 26    VY4X6SQ5AE  Coifa Alavanca Câmbio Gol Voyage Parati Saveir...
# 27    FADIUE4J4I   Chuteira Futebol De Salão Nike  Acc Mercurial...
# 28    K617ZEB4HN  Kit Irrigação Gotejamento 20 -  Ga2 + 100 Mts ...
# 29    ADZ6FG26CJ  Calcinha Infantil My Little Pony Kit Com 3 Pçs...
# ...          ...                                                ...
# 3962  V121JKYFVY  3cabo Usb Tipo C Samsung Original Galaxy S8 E ...
# 3963  ZY07CQVW6O  Multimídia Mp5 Player Bluetooth Automotivo 2 D...
# 3964  GPCD04T8YP  Kit 4 Bermuda Moleton Masculina Short Fitness ...
# 3965  B7V5Q79EL7  Queima!! Kit 12 Pacote Munição 4000 Bolinhas A...
# 3966  XU7NTE7SY1        Almofada De Amamentação Coroa Reizinho Azul
# 3967  HSIMOT5E90  Relógio Feminino G Shók Analogico Digital Auto...
# 3968  TA6SNWF5YU  Farol New Civic 2006 2007 2008 2009 2010 2011 ...
# 3969  W3R2A4DV2S  Cloro Piscina 3em1 10kg (combine O Frete Antes...
# 3970  DC4D8I6CCS  Kit 2x Isolate Protein Mix 2kg Profit - Bcaa G...
# 3971  BRTK3HR0B3  10 Almofadas Decorativas Para Ou Sua Sala Ou S...
# 3972  Y2M509P6DB     Fonte Poe Compacta 48v 0,5a Com Led - Internet
# 3973  LDMT5KSGW7  Clareador Whiteness Perfect Simple Original Ge...
# 3974  GW59YD6055  Maquina Faz Crepe -- Crepeira Semi Profissiona...
# 3975  OPS7V52R7G  Perfume Bulgari Extreme Pour Homme 100ml - Ori...
# 3976  WD8ZP598O8  Válvula Solenóide Para Mig Balmer 250mk/k/lk.0...
# 3977  EZ4BYREARI  Canivete Cartão Dobrável Cardsharp Iain Sincla...
# 3978  F266N31VSV  Trava Cadeado Freio De Disco Cb 300 Titan Univ...
# 3979  CP2UUAZ543  5 Válvula De Serviço Refrigeração Schrader 1/4...
# 3980  TQW7TARXSO               Keratina Em Gel Vitaminada 10 Litros
# 3981  J74UOK772C  Porta Condimentos Suporte Giratório Para 12 Po...
# 3982  WFGA3SVH6I  Top Cropped Feminino Sutiã Jeans Renda Sustent...
# 3983  GXQOLSSN6S  Mesa Dobravel Maxchief 1.22 M Regulagem De Altura
# 3984  LNXGY7DV0X                                   Bolo Fake Batman
# 3985  KOAQAZ7RGC  Teclado Bluetooth Padrão Apple P/ Smartphone T...
# 3986  SPXM4DV9UU  Carrinho De Bebê Para Gêmeos Hercules - Grafit...
# 3987  GPWP5IFQEN  Pochete Feminina Gucci - Coleção Inspirada Em ...
# 3988  OFLRK20BUP  Mini Massageador Portátil À Pilha Ou Usb 3 Pon...
# 3989  MQICEHKRH5      Óleo Castrol 5w40 Magnatec Stop Start Kit C/4
# 3990  ANYX5441IO  Antena Ubiquiti Litebeam Lbe-m5-23 23dbi 5ghz ...
# 3991  S4YVILX78R      Kit Com 20 Agulhas De Madeira Croche Com Case
#
# [3992 rows x 12 columns]

# %% [markdown]
# ## Actividad 4:
#
# Parsear la columna de atributos y extraer a columnas propias aquellos atributos cuyo `id` sea `BRAND` o `MODEL`. Estos atributos representan marca o modelo que el vendedor del item ingresó en la publicación. [Opcional] No es necesario limitarse a estos dos atributos, se puede probar quedarse con los N atributos más frecuentes.

# %%
def attribute_to_list(attribute):
    if attribute:
        return literal_eval(attribute)
    else:
        return []

# %%
# myString = df["ATTRIBUTES"][1].strip('[ ]')
# attribute_to_list(myString)
# json_normalize(attribute_to_list(myString))

# %%
#attribute_to_list(df["ATTRIBUTES"][1])

# %%
json_normalize(attribute_to_list(df["ATTRIBUTES"][1]))
# Out:
#   attribute_group_id attribute_group_name                id  \
# 0             OTHERS               Outros  BEDDING_SET_SIZE
# 1             OTHERS               Outros      BEDDING_TYPE
# 2             OTHERS               Outros             BRAND
# 3             OTHERS               Outros              GTIN
# 4             OTHERS               Outros    ITEM_CONDITION
# 5             OTHERS               Outros             MODEL
#
#                           name value_id   value_name
# 0                      Tamanho  5774457     Solteiro
# 1        Tipo de roupa de cama      NaN  MOSQUITEIRO
# 2                        Marca      NaN       CAMELO
# 3  Código universal de produto       -1          NaN
# 4             Condição do item  2230284         Novo
# 5                       Modelo  3176642     Solteiro

# %%
#datos = myString.replace("'", '"')

# FALTA EXTRAER BRAND Y MODEL EN CADA CASO Y LUEGO ITERAR!!!!!!!!!!!!!!!!

# %% [markdown]
# ## Actividad 5:
#
# Transformar variables categóricas en números (Se recomienda OneHotEncoding) para las columnas (Sugerencia: arrancar con un sample de ~10K items)

# %%
df.sample(2)
# luego agregar las variables generadas a partir de atributes
# Out:
#             SHP_WEIGHT  SHP_LENGTH  SHP_WIDTH  SHP_HEIGHT  \
# ITEM_ID
# U6NI92WT84       306.0        66.0       14.0        14.0
# DMCDU0W932      1300.0        25.0       11.0         5.0
#
#                                                    ATTRIBUTES  \
# ITEM_ID
# U6NI92WT84  [{'id': 'EAN', 'name': 'EAN', 'value_id': None...
# DMCDU0W932  [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...
#
#            CATALOG_PRODUCT_ID CONDITION                   DOMAIN_ID  PRICE  \
# ITEM_ID
# U6NI92WT84         H53U1H7Q5G       new    MLB-COLLECTIBLE_PRODUCTS   70.0
# DMCDU0W932         H53U1H7Q5G      used  MLB-MOBILE_DEVICE_CHARGERS    6.0
#
#              SELLER_ID                                              TITLE
# ITEM_ID
# U6NI92WT84  MZ4QB55VPU  Adesivo Recortado Parede Quebrada Rota 66 Rodovia
# DMCDU0W932  XOO89UQKJD  Carregador Original Nokia Pino Fino C3/e71-72-...

# %%
# Exploración de cantidad de categorías distintas
print(pd.DataFrame(df.CATALOG_PRODUCT_ID.unique()).count())
print(pd.DataFrame(df.CONDITION.unique()).count())
print(pd.DataFrame(df.DOMAIN_ID.unique()).count())
print(pd.DataFrame(df.SELLER_ID.unique()).count())
print(pd.DataFrame(df.TITLE.unique()).count())
# Out:
# 0    426
# dtype: int64
# 0    3
# dtype: int64
# 0    882
# dtype: int64
# 0    3180
# dtype: int64
# 0    3975
# dtype: int64

# %%
column = 'CATALOG_PRODUCT_ID'
lb = LabelBinarizer()
lb_results = lb.fit_transform(df[column])
#pd.DataFrame(lb_results, columns=(column + '_') + pd.Series(lb.classes_)).head(10)
CATALOG_PRODUCT_ID_ENCODED = pd.DataFrame(lb_results, columns=(column + '_') + pd.Series(lb.classes_))
CATALOG_PRODUCT_ID_ENCODED.sample(5)
# Out:
#       CATALOG_PRODUCT_ID_A0RY70BE19  CATALOG_PRODUCT_ID_A2H2JJFBXM  \
# 1196                              0                              0
# 2382                              0                              0
# 3335                              0                              0
# 2519                              0                              0
# 1969                              0                              0
#
#       CATALOG_PRODUCT_ID_A4M0AP2TSK  CATALOG_PRODUCT_ID_A6X73QCLS9  \
# 1196                              0                              0
# 2382                              0                              0
# 3335                              0                              0
# 2519                              0                              0
# 1969                              0                              0
#
#       CATALOG_PRODUCT_ID_A7Y7QKJ7EF  CATALOG_PRODUCT_ID_ADKMKF0FVM  \
# 1196                              0                              0
# 2382                              0                              0
# 3335                              0                              0
# 2519                              0                              0
# 1969                              0                              0
#
#       CATALOG_PRODUCT_ID_AF4WQUGCVH  CATALOG_PRODUCT_ID_AFPLIBE9VN  \
# 1196                              0                              0
# 2382                              0                              0
# 3335                              0                              0
# 2519                              0                              0
# 1969                              0                              0
#
#       CATALOG_PRODUCT_ID_AG9UI846DP  CATALOG_PRODUCT_ID_AGE41D6OTF  \
# 1196                              0                              0
# 2382                              0                              0
# 3335                              0                              0
# 2519                              0                              0
# 1969                              0                              0
#
#                   ...                CATALOG_PRODUCT_ID_ZCRDDN2XDD  \
# 1196              ...                                            0
# 2382              ...                                            0
# 3335              ...                                            0
# 2519              ...                                            0
# 1969              ...                                            0
#
#       CATALOG_PRODUCT_ID_ZD9PH6CQGT  CATALOG_PRODUCT_ID_ZE1SAQN048  \
# 1196                              0                              0
# 2382                              0                              0
# 3335                              0                              0
# 2519                              0                              0
# 1969                              0                              0
#
#       CATALOG_PRODUCT_ID_ZHPQEDV8OO  CATALOG_PRODUCT_ID_ZK6EHO4XIX  \
# 1196                              0                              0
# 2382                              0                              0
# 3335                              0                              0
# 2519                              0                              0
# 1969                              0                              0
#
#       CATALOG_PRODUCT_ID_ZNCNVOCZCI  CATALOG_PRODUCT_ID_ZOLFL65EFH  \
# 1196                              0                              0
# 2382                              0                              0
# 3335                              0                              0
# 2519                              0                              0
# 1969                              0                              0
#
#       CATALOG_PRODUCT_ID_ZSQJ90IBB0  CATALOG_PRODUCT_ID_ZUZF6Q39W8  \
# 1196                              0                              0
# 2382                              0                              0
# 3335                              0                              0
# 2519                              0                              0
# 1969                              0                              0
#
#       CATALOG_PRODUCT_ID_ZZDRE28WA4
# 1196                              0
# 2382                              0
# 3335                              0
# 2519                              0
# 1969                              0
#
# [5 rows x 426 columns]

# %%
df["CONDITION"]
# Out:
# ITEM_ID
# A0BKGTRNTM     new
# A0JIHFAMOP     new
# A0NG260OMQ     new
# A0WL6O455O     new
# A1957258HH    used
# A1FGLFZMVL     new
# A1JOTAU8V2     new
# A1LOUCXG9G     new
# A2C66XB6P7     new
# A2KCXCBL57     new
# A2RQ980UVM     new
# A3MNDIW032     NaN
# A43U8UOWPI     new
# A4G70EIGUH     new
# A4N2QZXPXK     new
# A56OPIMS0D     new
# A5IQMUAC28     new
# A5M6IPYV6M     new
# A5VAXDE1G8     new
# A61JSUNHMI     new
# A6TAE435H1     new
# A7EZZ96IDB     NaN
# A7F2YZUXKV     new
# A87VLI4UUY     new
# A8GKANTGUK     new
# A8IVK9CICB     new
# A8Y5P3MCVJ     new
# A9495T93S4     NaN
# A9CQEUN6IU     new
# A9GGUJPPSA     new
#               ...
# ZU48DBNUUA     NaN
# ZU4ZP1JHMN     new
# ZU718W1552     NaN
# ZUP27NZFS3     new
# ZUXD6OD8M8     new
# ZV3JHGL1ID     new
# ZV3X8Y08U4     new
# ZVI8QNVYMF     new
# ZVPL70J9OG     NaN
# ZW5TA6CP0X     new
# ZWA6IVO4NM     NaN
# ZWOU76VN42     new
# ZWRX53K52L     new
# ZWT684RYRA     NaN
# ZWWQQV4FWN     new
# ZX4STUTFBN     new
# ZXIAW22XI3     new
# ZXT4P7WYU5     new
# ZXVQ7O6NDG     new
# ZXY1TK6LFC     new
# ZXZXFADE2B     new
# ZYD4THZKT0     NaN
# ZYNLMDVYEG     new
# ZYR4SBZB4H     new
# ZYUOIR3H5I     new
# ZZ50AZ3OAK     new
# ZZ8ERDIFP4     new
# ZZFFUBJ43D     new
# ZZWAKWIMPT     new
# ZZXLYGKXNE     NaN
# Name: CONDITION, Length: 3992, dtype: object

# %%
column = "CONDITION"
lb = LabelBinarizer()
lb_results = lb.fit_transform(df[column].astype(str))
pd.DataFrame(lb_results, columns=(column + '_') + pd.Series(lb.classes_)).head(10)
CONDITION_ENCODED = pd.DataFrame(lb_results, columns=(column + '_') + pd.Series(lb.classes_))
CONDITION_ENCODED.sample(5)
# Out:
#       CONDITION_nan  CONDITION_new  CONDITION_not_specified  CONDITION_used
# 2624              0              1                        0               0
# 2389              0              1                        0               0
# 2372              0              1                        0               0
# 3013              0              1                        0               0
# 3236              0              1                        0               0

# %%
column = 'DOMAIN_ID'
lb = LabelBinarizer()
lb_results = lb.fit_transform(df[column].astype(str))
#pd.DataFrame(lb_results, columns=(column + '_') + pd.Series(lb.classes_)).head(10)
DOMAIN_ID_ENCODED = pd.DataFrame(lb_results, columns=(column + '_') + pd.Series(lb.classes_))
DOMAIN_ID_ENCODED.sample(5)
# Out:
#       DOMAIN_ID_MLB-ABS_SENSORS  DOMAIN_ID_MLB-ACOUSTIC_GUITARS  \
# 704                           0                               0
# 2514                          0                               0
# 2612                          0                               0
# 354                           0                               0
# 1705                          0                               0
#
#       DOMAIN_ID_MLB-ACTION_FIGURES  DOMAIN_ID_MLB-ADHESIVE_TAPES  \
# 704                              0                             0
# 2514                             0                             0
# 2612                             0                             0
# 354                              0                             0
# 1705                             0                             0
#
#       DOMAIN_ID_MLB-AEROBICS_AND_FITNESS_EQUIPMENT  \
# 704                                              0
# 2514                                             0
# 2612                                             0
# 354                                              0
# 1705                                             0
#
#       DOMAIN_ID_MLB-AIRGUN_PELLETS  DOMAIN_ID_MLB-AIRSOFT_GUNS  \
# 704                              0                           0
# 2514                             0                           0
# 2612                             0                           0
# 354                              0                           0
# 1705                             0                           0
#
#       DOMAIN_ID_MLB-AIR_CONDITIONER_REMOTE_CONTROLS  \
# 704                                               0
# 2514                                              0
# 2612                                              0
# 354                                               0
# 1705                                              0
#
#       DOMAIN_ID_MLB-AIR_FRESHENERS  DOMAIN_ID_MLB-ALARMS_AND_SENSORS  \
# 704                              0                                 0
# 2514                             0                                 0
# 2612                             0                                 0
# 354                              0                                 0
# 1705                             0                                 0
#
#           ...        DOMAIN_ID_MLB-WIRELESS_ANTENNAS  \
# 704       ...                                      0
# 2514      ...                                      0
# 2612      ...                                      0
# 354       ...                                      0
# 1705      ...                                      0
#
#       DOMAIN_ID_MLB-WIRELESS_CHARGERS  DOMAIN_ID_MLB-WIRELESS_FM_TRANSMITTERS  \
# 704                                 0                                       0
# 2514                                0                                       0
# 2612                                0                                       0
# 354                                 0                                       0
# 1705                                0                                       0
#
#       DOMAIN_ID_MLB-WIRE_STRIPPERS  DOMAIN_ID_MLB-WOMEN_SWIMWEAR  \
# 704                              0                             0
# 2514                             0                             0
# 2612                             0                             0
# 354                              0                             0
# 1705                             0                             0
#
#       DOMAIN_ID_MLB-WRENCHES  DOMAIN_ID_MLB-WRENCH_SETS  \
# 704                        0                          0
# 2514                       0                          0
# 2612                       0                          0
# 354                        0                          0
# 1705                       0                          0
#
#       DOMAIN_ID_MLB-WRISTWATCHES  DOMAIN_ID_MLB-XENON_KITS  DOMAIN_ID_nan
# 704                            0                         0              0
# 2514                           0                         0              0
# 2612                           0                         0              0
# 354                            0                         0              0
# 1705                           0                         0              0
#
# [5 rows x 883 columns]

# %%
column = 'SELLER_ID'
lb = LabelBinarizer()
lb_results = lb.fit_transform(df[column].astype(str))
#pd.DataFrame(lb_results, columns=(column + '_') + pd.Series(lb.classes_)).head(10)
SELLER_ID_ENCODED = pd.DataFrame(lb_results, columns=(column + '_') + pd.Series(lb.classes_))
SELLER_ID_ENCODED.sample(5)
# Out:
#       SELLER_ID_A0C377D6IK  SELLER_ID_A0G4VA0XM9  SELLER_ID_A0GTKIHE1A  \
# 2386                     0                     0                     0
# 2969                     0                     0                     0
# 2114                     0                     0                     0
# 950                      0                     0                     0
# 185                      0                     0                     0
#
#       SELLER_ID_A0KW5KL0S5  SELLER_ID_A115K1RP2T  SELLER_ID_A1QE03ELPN  \
# 2386                     0                     0                     0
# 2969                     0                     0                     0
# 2114                     0                     0                     0
# 950                      0                     0                     0
# 185                      0                     0                     0
#
#       SELLER_ID_A2K70P3I18  SELLER_ID_A2PJ265JWZ  SELLER_ID_A3I3O11AE1  \
# 2386                     0                     0                     0
# 2969                     0                     0                     0
# 2114                     0                     0                     0
# 950                      0                     0                     0
# 185                      0                     0                     0
#
#       SELLER_ID_A4SE36Z2TG          ...           SELLER_ID_ZU5MPG54HI  \
# 2386                     0          ...                              0
# 2969                     0          ...                              0
# 2114                     0          ...                              0
# 950                      0          ...                              0
# 185                      0          ...                              0
#
#       SELLER_ID_ZUM6UCCICB  SELLER_ID_ZVW99W8TBU  SELLER_ID_ZW0R4QP48J  \
# 2386                     0                     0                     0
# 2969                     0                     0                     0
# 2114                     0                     0                     0
# 950                      0                     0                     0
# 185                      0                     0                     0
#
#       SELLER_ID_ZWDY6BPHGS  SELLER_ID_ZXCKFJHKGT  SELLER_ID_ZXFTE5ZZ00  \
# 2386                     0                     0                     0
# 2969                     0                     0                     0
# 2114                     0                     0                     0
# 950                      0                     0                     0
# 185                      0                     0                     0
#
#       SELLER_ID_ZY07CQVW6O  SELLER_ID_ZYUC8GTM87  SELLER_ID_ZZCYH6OP0M
# 2386                     0                     0                     0
# 2969                     0                     0                     0
# 2114                     0                     0                     0
# 950                      0                     0                     0
# 185                      0                     0                     0
#
# [5 rows x 3180 columns]

# %%
column = 'TITLE'
lb = LabelBinarizer()
lb_results = lb.fit_transform(df[column].astype(str))
#pd.DataFrame(lb_results, columns=(column + '_') + pd.Series(lb.classes_)).head(10)
TITLE_ENCODED = pd.DataFrame(lb_results, columns=(column + '_') + pd.Series(lb.classes_))
TITLE_ENCODED.sample(5)
# Out:
#       TITLE_  Unifi Ponto De Acesso Ao Ar Livre 802.11ac  \
# 2044                                                  0
# 2633                                                  0
# 962                                                   0
# 2236                                                  0
# 2416                                                  0
#
#       TITLE_ 10 Regata Masculina Dry Fit  Poliester Esportes Academia   \
# 2044                                                  0
# 2633                                                  0
# 962                                                   0
# 2236                                                  0
# 2416                                                  0
#
#       TITLE_ 3  Composto Natural Dieta  Multi Ervas 60 Caps   \
# 2044                                                  0
# 2633                                                  0
# 962                                                   0
# 2236                                                  0
# 2416                                                  0
#
#       TITLE_ Blusa   Listra Tecido Moletom Ref.15349  \
# 2044                                               0
# 2633                                               0
# 962                                                0
# 2236                                               0
# 2416                                               0
#
#       TITLE_ Bota Coturno Feminina Atacado 7 Pares Revenda  \
# 2044                                                  0
# 2633                                                  0
# 962                                                   0
# 2236                                                  0
# 2416                                                  0
#
#       TITLE_ Bota Feminina Montaria Cano Alto Full Jln741  \
# 2044                                                  0
# 2633                                                  0
# 962                                                   0
# 2236                                                  0
# 2416                                                  0
#
#       TITLE_ Bucha Do Eixo E Do Amortecedor Traseiro Do Peugeot 206 Heat  \
# 2044                                                  0
# 2633                                                  0
# 962                                                   0
# 2236                                                  0
# 2416                                                  0
#
#       TITLE_ Caixa De Som Xtreme Mini  Bluetooth Usb 40w Primeira Linha  \
# 2044                                                  0
# 2633                                                  0
# 962                                                   0
# 2236                                                  0
# 2416                                                  0
#
#       TITLE_ Calça Feminina Cirre Nervurada Nervuras Cintura Alta Justa  \
# 2044                                                  0
# 2633                                                  0
# 962                                                   0
# 2236                                                  0
# 2416                                                  0
#
#       TITLE_ Camisa Long Line Oversized Swag Masculina  \
# 2044                                                 0
# 2633                                                 0
# 962                                                  0
# 2236                                                 0
# 2416                                                 0
#
#                                     ...                                 \
# 2044                                ...
# 2633                                ...
# 962                                 ...
# 2236                                ...
# 2416                                ...
#
#       TITLE_Óculos Oakley Tailend Lente Ice Thug + Brindes + F Grátis   \
# 2044                                                  0
# 2633                                                  0
# 962                                                   0
# 2236                                                  0
# 2416                                                  0
#
#       TITLE_Óculos Para Maquiagem Lente Giratória +3  Unidade  \
# 2044                                                  0
# 2633                                                  0
# 962                                                   0
# 2236                                                  0
# 2416                                                  0
#
#       TITLE_Óleo 5100 4t 15w50 1 Litro - Motul  \
# 2044                                         0
# 2633                                         0
# 962                                          0
# 2236                                         0
# 2416                                         0
#
#       TITLE_Óleo Castrol 5w40 Magnatec Stop Start Kit C/ 5  \
# 2044                                                  0
# 2633                                                  0
# 962                                                   0
# 2236                                                  0
# 2416                                                  0
#
#       TITLE_Óleo Castrol 5w40 Magnatec Stop Start Kit C/4  \
# 2044                                                  0
# 2633                                                  0
# 962                                                   0
# 2236                                                  0
# 2416                                                  0
#
#       TITLE_Óleo Coco Extra Virgem Ladir 3, Lt + 1 Kg Sal + Vinagre Maçã  \
# 2044                                                  0
# 2633                                                  0
# 962                                                   0
# 2236                                                  0
# 2416                                                  0
#
#       TITLE_Óleo Do Motor Incol Alta Performance 25w60 Sl 1l  \
# 2044                                                  0
# 2633                                                  0
# 962                                                   0
# 2236                                                  0
# 2416                                                  0
#
#       TITLE_Óleo Do Motor Ipiranga F1 Master 15w40 Sl Semissintético 1l  \
# 2044                                                  0
# 2633                                                  0
# 962                                                   0
# 2236                                                  0
# 2416                                                  0
#
#       TITLE_Óleo Pentosin Hc 5w40 Sintético Pentosynth Kit C/5 Promoção  \
# 2044                                                  0
# 2633                                                  0
# 962                                                   0
# 2236                                                  0
# 2416                                                  0
#
#       TITLE_Ônibus 1/50 Na Caixa Viagem Internacional Escolar Caravana
# 2044                                                  0
# 2633                                                  0
# 962                                                   0
# 2236                                                  0
# 2416                                                  0
#
# [5 rows x 3975 columns]

# %%
#data= df.CATALOG_PRODUCT_ID
#values = np.array(data)
#print(values)
# integer encode
#label_encoder = LabelEncoder()
#integer_encoded = label_encoder.fit_transform(values)
#print(integer_encoded)
# binary encode
#onehot_encoder = OneHotEncoder(sparse=False)
#integer_encoded = integer_encoded.reshape(len(integer_encoded), 1)
#onehot_encoded = onehot_encoder.fit_transform(integer_encoded)
#print(onehot_encoded)

# %% [markdown]
# ## Actividad 6:
#
# En caso de tener alguna variable no medida (en nuestro caso `PRICE`) imputar sus valores utilizando kNN.

# %%
from fancyimpute import KNN 
train_cols = list(df)
train = pd.DataFrame(KNN(k=5).complete(train))
train.columns = train_cols
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-29-b2f0e73796a1> in <module>()
# ----> 1 from fancyimpute import KNN
#       2 train_cols = list(df)
#       3 train = pd.DataFrame(KNN(k=5).complete(train))
#       4 train.columns = train_cols
#
# ModuleNotFoundError: No module named 'fancyimpute'

# %%
list(df)
# Out:
# ['SHP_WEIGHT',
#  'SHP_LENGTH',
#  'SHP_WIDTH',
#  'SHP_HEIGHT',
#  'ATTRIBUTES',
#  'CATALOG_PRODUCT_ID',
#  'CONDITION',
#  'DOMAIN_ID',
#  'PRICE',
#  'SELLER_ID',
#  'TITLE']

# %% [markdown]
# ## Actividad 7:
#
# Medir las distribuciones de las variables como histogramas, realizar normalizaciones e identificar outliers con los métodos vistos en clase. Hacer análisis de estos outliers y considerar si sería correcto o no eliminarlos del dataset. Sugerencia: Identificar outliers de las columnas `SHP_WEIGHT` y `SHP_VOLUME`, donde `SHP_VOLUME` se define como el producto de las dimensiones.

# %%
# creación de la variable SHP_VOLUME
df["SHP_VOLUME"] = df["SHP_LENGTH"] * df["SHP_WIDTH"] * df["SHP_HEIGHT"]

# %%
df.sample(3)
# Out:
#             SHP_WEIGHT  SHP_LENGTH  SHP_WIDTH  SHP_HEIGHT  \
# ITEM_ID
# DBLHO51K70       470.0        20.0       16.0        11.0
# LX43KDK9BL       100.0        25.0       11.0         5.0
# UJJ88F3V9K      3556.0        25.0       11.0         5.0
#
#                                                    ATTRIBUTES  \
# ITEM_ID
# DBLHO51K70  [{'id': 'ALPHANUMERIC_MODEL', 'name': 'Modelo ...
# LX43KDK9BL  [{'id': 'BRAND', 'name': 'Marca da película', ...
# UJJ88F3V9K  [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...
#
#            CATALOG_PRODUCT_ID CONDITION  \
# ITEM_ID
# DBLHO51K70         H53U1H7Q5G       new
# LX43KDK9BL         H53U1H7Q5G       new
# UJJ88F3V9K         H53U1H7Q5G       new
#
#                                              DOMAIN_ID   PRICE   SELLER_ID  \
# ITEM_ID
# DBLHO51K70                                MLB-SPEAKERS   31.90  LOO0BZ4B9U
# LX43KDK9BL  MLB-CELLPHONE_AND_TABLET_SCREEN_PROTECTORS   18.99  MB4PVRMGL8
# UJJ88F3V9K           MLB-ELECTRONIC_ENTRANCE_INTERCOMS  447.02  F58FWUVIWA
#
#                                                         TITLE  SHP_VOLUME
# ITEM_ID
# DBLHO51K70  Caixa De Som Bluetooth Portátil 15w Mp3 Rádio ...      3520.0
# LX43KDK9BL  Película Vidro Temperado Sony Xperia Xa1 Ultra...      1375.0
# UJJ88F3V9K  Kit Porteiro Eletronico C/ Video Monitor Cftv ...      1375.0
